# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
model_name = "Qwen/Qwen2.5-14B-Instruct"

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    load_in_8bit=True,
    torch_dtype=torch.bfloat16,
    device_map="cuda:0",
)
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]

# %%
from fullrag import llmmodel

import time
start_time = time.time()

rag = llmmodel(llm_model_name = "Qwen/Qwen2.5-7B-Instruct")
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
start_time = time.time()
print(rag.generate_answer("Как подключить монетизацию на платформе рутуба?"))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
#            Ответь на следующий вопрос, используя дополнительную информацию (контекст) которую я тебе дам.
#
#             Вопрос пользователя, на который ты должен дать ответ: Как подключить монетизацию на платформе рутуба?
#
#             Контекст:
#             1) Подходящяя информация, которую ты можешь использовать при ответе на основной вопрос: ['Пример вопроса и ответа: Что такое Монетизация на RUTUBE | Монетизация | На рутубе есть монетизация | Монетизацию можно подключить после того как вы загрузите в публичный доступ на свой канал минимум  ролика и наберёте   просмотров Мы считаем совокупное количество просмотров начиная с  января   года По порядку о том как это работает В разделе «Монетизация» в Студии RUTUBE у вас появится анкета партнёра  Заполните её и подайте заявку на монетизацию Мы убедимся что ваш канал не нарушает правил RUTUBE и пришлём подтверждение вам на почту RUTUBE начнёт начислять вам вознаграждение в порядке определенном Офертой   Всю аналитику и размер дохода по месяцам вы сможете смотреть в личном кабинете Студии RUTUBE Творите загружайте и выводите свой канал в топ', 'Пример вопроса и ответа: Что такое Монетизация на RUTUBE | Монетизация | На рутубе есть монетизация | Монетизацию можно подключить после того как вы загрузите в публичный доступ на свой канал минимум  ролика и наберёте   просмотров Мы считаем совокупное количество просмотров начиная с  января   года По порядку о том как это работает В разделе «Монетизация» в Студии RUTUBE у вас появится анкета партнёра  Заполните её и подайте заявку на монетизацию Мы убедимся что ваш канал не нарушает правил RUTUBE и пришлём подтверждение вам на почту RUTUBE начнёт начислять вам вознаграждение в порядке определенном Офертой   Всю аналитику и размер дохода по месяцам вы сможете смотреть в личном кабинете Студии RUTUBE Творите загружайте и выводите свой канал в топ', 'Пример вопроса и ответа: Как подключиться к партнерской программе в приложении Студия RUTUBE | Мобильное приложение Студия RUTUBE на Android | Как в студии рутуба на телефоне подать заявку на монетизацию | На данный момент в приложении такой возможности нет но вы можете подключиться к партнерской программе в веб версии Студии в разделе Монетизация  Подробнее про подключение к партнерской программе']
#
#             2) Подходящяя информация из Условий Размещения на платформе: ['Пользователь/Автор на платформе не получает вознаграждение за загружаемые материалы, если это не предусмотрено Соглашением или специальными условиями. Для участия в программе монетизации контента необходимо подать заявку на статус Партнера, при условии, что общий объем просмотров контента на Канале превышает 5 000, с минимальной продолжительностью каждого просмотра 60 секунд. Администрация также присваивает Индивидуальный Медиаиндикатор Поведенческой Активности (ИМПА) после достижения 1 000 просмотров, который начисляется в условных единицах и зависит от поведения пользователей с контентом. Условия начисления ИМПА определены в Приложении «Б» Соглашения, обязательном для ознакомления.']
#
#             3) Подходящяя информация из Пользовательского соглашения: ['Условия размещения контента на платформе RUTUBE подразумевают возможность интеграции интерфейса Личного кабинета Пользователя или Канала Пользователя с Монетизационными сервисами по усмотрению Администрации, информация о которой детально изложена в Приложении «Г» к Соглашению, доступном на сайте.']
#
# Чтобы подключиться к программе монетизации на RUTUBE, вам нужно выполнить несколько шагов:
#
# 1. Загрузите в публичный доступ минимум 1 видео и наберите 5,00000 просмотров.
# 2. После достижения необходимого количества просмотров, в разделе «Монетизация» в Студии RUTUBE появится анкета партнёра.
# 3. Заполните анкету и подайте заявку на монетизацию.
# 4. После проверки вашего канала администрацией RUTUBE, вам будет отправлено подтверждение на почту.
# 5. RUTUBE начнёт начислять вам вознаграждение согласно условиям Оферты.
# 6. В личном кабинете Студии RUTUBE вы сможете отслеживать свою аналитику и размер дохода по месяцам.
# --- 51.71678805351257 seconds ---
