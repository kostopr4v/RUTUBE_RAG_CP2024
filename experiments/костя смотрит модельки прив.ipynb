# %%
from fullrag import llmmodel

import time
start_time = time.time()

rag = llmmodel()
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
start_time = time.time()
print(rag.generate_answer("Что нельзя публиковать на платформе RUTUBE?"))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# На платформе RUTUBE нельзя публиковать следующий контент:
#
# 1. Чужой контент без разрешения автора или правообладателя, например музыку, видео и изображения из общего доступа, записи концерров, фильмов, аудиокниг, фрагменты новостных сюжетов из ТВ-эфиров, видео популярных блогерров, трансляции спортивных событий.
#
# 2. Рекламу трансцендентных услуг, например рекламу гаданий, услуг ясновидущих, экстрасенсов и т.д.
#
# 3. Откровенно сексуальный контент, например танцы в откровенных костюмах, рекламу интимных товаров или сексуальных услуг.
#
# 4. Реклму букмекеров, проведение ставок и пропаганду любых азартных игр.
#
# 5. Реклму или продвижение финансовых пирамид и сетевого маркетинга (MLM), преподнесение их в качестве надёжного источника заработка.
#
# 6. Нецензурную брань, оскорбления, подстрекательства к незакакнным действиям.
#
# 7. Контент, который нацелен только на перенаправление зрителов на другие сайты.
#
# ...
